# %%
from live_rail.wrappers.rail_svc_wrapper import RailSvcCatalogWrapper

# %%
from pathlib import Path
import nest_asyncio
from rail.utils import catalog_utils
from rail_svc import db, local_sync
nest_asyncio.apply()

# %%
try:
    await db.close_db()
except:
    pass
db.init_db()

catalog_utils.load_yaml(catalog_utils.DEFAULT_CATAlOG_TAG_FILE)

# %%
wrapper = RailSvcCatalogWrapper(1)

# %%
obj_wrapper = wrapper.get_object(5)

# %%
obj_wrapper.get_magnitude_errors()
